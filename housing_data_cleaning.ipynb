# %%
import pandas as pd

# %%
city_data = pd.read_csv("../City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
city_data.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       City        NY    NY
# 1     12447         1  Los Angeles       City        CA    CA
# 2     39051         2      Houston       City        TX    TX
# 3     17426         3      Chicago       City        IL    IL
# 4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1/31/2000  2/29/2000  \
# 0       New York-Newark-Jersey City       Queens County   252885.0   254706.0
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County   237820.0   238043.0
# 2  Houston-The Woodlands-Sugar Land       Harris County   109356.0   109367.0
# 3          Chicago-Naperville-Elgin         Cook County   169115.0   169519.0
# 4         San Antonio-New Braunfels        Bexar County   116095.0   116277.0
#
#    ...  7/31/2021  8/31/2021  9/30/2021  10/31/2021  11/30/2021  12/31/2021  \
# ...

# %%
city_data.shape
# Out:
# (22423, 276)

# %%
city_data.iloc[:,6].value_counts()
# Out:
# New York-Newark-Jersey City        511
# Chicago-Naperville-Elgin           353
# St. Louis                          247
# Washington-Arlington-Alexandria    238
# Philadelphia-Camden-Wilmington     232
#                                   ...
# Gallup                               1
# Arcadia                              1
# Los Alamos                           1
# Okeechobee                           1
# Seneca Falls                         1
# Name: Metro, Length: 857, dtype: int64

# %%
city_data[city_data['Metro']=="Austin-Round Rock"]
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State  \
# 10        10221        10         Austin       City        TX    TX
# 210       26857       215     Round Rock       City        TX    TX
# 485       45417       496     Georgetown       City        TX    TX
# 501       47080       512   Pflugerville       City        TX    TX
# 657       40738       676     San Marcos       City        TX    TX
# ...         ...       ...            ...        ...       ...   ...
# 20660     44301     26880     Briarcliff       City        TX    TX
# 20920     42864     27361  Point Venture       City        TX    TX
# 21396     56827     28227           Weir       City        TX    TX
# 21476     39906     28392  Mountain City       City        TX    TX
# 22048    233935     29449           Hays       City        TX    TX
#
#                    Metro         CountyName  1/31/2000  2/29/2000  ...  \
# 10     Austin-Round Rock      Travis County   199734.0   200778.0  ...
# ...

# %%
dates = city_data.iloc[:,8:].columns.to_list()
dates
# Out:
# ['1/31/2000',
#  '2/29/2000',
#  '3/31/2000',
#  '4/30/2000',
#  '5/31/2000',
#  '6/30/2000',
#  '7/31/2000',
#  '8/31/2000',
#  '9/30/2000',
#  '10/31/2000',
#  '11/30/2000',
#  '12/31/2000',
#  '1/31/2001',
#  '2/28/2001',
#  '3/31/2001',
#  '4/30/2001',
#  '5/31/2001',
#  '6/30/2001',
#  '7/31/2001',
#  '8/31/2001',
#  '9/30/2001',
#  '10/31/2001',
#  '11/30/2001',
#  '12/31/2001',
#  '1/31/2002',
#  '2/28/2002',
#  '3/31/2002',
#  '4/30/2002',
#  '5/31/2002',
#  '6/30/2002',
#  '7/31/2002',
#  '8/31/2002',
#  '9/30/2002',
#  '10/31/2002',
#  '11/30/2002',
#  '12/31/2002',
#  '1/31/2003',
#  '2/28/2003',
#  '3/31/2003',
#  '4/30/2003',
#  '5/31/2003',
#  '6/30/2003',
#  '7/31/2003',
#  '8/31/2003',
#  '9/30/2003',
#  '10/31/2003',
#  '11/30/2003',
#  '12/31/2003',
#  '1/31/2004',
#  '2/29/2004',
#  '3/31/2004',
#  '4/30/2004',
#  '5/31/2004',
#  '6/30/2004',
#  '7/31/2004',
#  '8/31/2004',
#  '9/30/2004',
#  '10/31/2004',
#  '11/30/2004',
#  '12/31/2004',
#  '1/31/2005',
# ...

# %%
price_melt = pd.melt(city_data, id_vars=['RegionID'],value_vars = dates,var_name='Date',value_name='Home_Cost').sort_values(by='RegionID')
price_melt
# Out:
#          RegionID        Date  Home_Cost
# 2341630      3300   9/30/2008        NaN
# 5032390      3300   9/30/2018   150668.0
# 1355018      3300   1/31/2005        NaN
# 996250       3300   9/30/2003        NaN
# 2745244      3300   3/31/2010        NaN
# ...           ...         ...        ...
# 3481558    760887  12/31/2012   193243.0
# 2517369    760887   5/31/2009   232544.0
# 3033098    760887   4/30/2011   209590.0
# 5679012    760887   2/28/2021   249860.0
# 925336     760887   6/30/2003   168218.0
#
# [6009364 rows x 3 columns]
